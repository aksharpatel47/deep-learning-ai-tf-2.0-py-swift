# %% [markdown]
# ## Implementing Logistic Regression from Scratch using TensorFlow 2.0
#
# We'll be using two approaches to implement logistic regression classifier using TensorFlow 2.0.
#
# 1. Implementing it from scratch using vector operations
# 2. Using keras to create a single layer neural network that works like a logistic regression classifier
#
# ### Downloading the dataset to be used
#
# We'll be using cats vs dogs dataset available from tensorflow datasets to train our classifier

# %%
import tensorflow_datasets as tfds
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
train, test = tfds.load("cats_vs_dogs", split='train[:80%]'), tfds.load("cats_vs_dogs", split="train[-80%:]")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-809d5fd240f7> in <module>
# ----> 1 train, test = tfds.load("cats_vs_dogs", split="train[:80%]"), tfds.load("cats_vs_dogs", split="train[-80%:]")
#
# ~\AppData\Roaming\Python\Python37\site-packages\wrapt\wrappers.py in __call__(self, *args, **kwargs)
#     562
#     563         return self._self_wrapper(self.__wrapped__, self._self_instance,
# --> 564                 args, kwargs)
#     565
#     566 class BoundFunctionWrapper(_FunctionWrapperBase):
#
# ~\Miniconda3\envs\tf2\lib\site-packages\tensorflow_datasets\core\api_utils.py in disallow_positional_args_dec(fn, instance, args, kwargs)
#      50     _check_no_positional(fn, args, ismethod, allowed=allowed)
#      51     _check_required(fn, kwargs)
# ---> 52     return fn(*args, **kwargs)
#      53
#      54   return disallow_positional_args_dec(wrapped)  # pylint: disable=no-value-for-parameter
#
# ~\Miniconda3\envs\tf2\lib\site-packages\tensorflow_datasets\core\registered.py in load(name, split, data_dir, batch_size, in_memory, shuffle_files, download, as_supervised, decoders, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs)
#     310   as_dataset_kwargs.setdefault("shuffle_files", shuffle_files)
#     311
# --> 312   ds = dbuilder.as_dataset(**as_dataset_kwargs)
#     313   if with_info:
#     314     return ds, dbuilder.info
#
# ~\AppData\Roaming\Python\Python37\site-packages\wrapt\wrappers.py in __call__(self, *args, **kwargs)
#     601
#     602             return self._self_wrapper(self.__wrapped__, self._self_instance,
# --> 603                     args, kwargs)
#     604
#     605         else:
#
# ~\Miniconda3\envs\tf2\lib\site-packages\tensorflow_datasets\core\api_utils.py in disallow_positional_args_dec(fn, instance, args, kwargs)
#      50     _check_no_positional(fn, args, ismethod, allowed=allowed)
#      51     _check_required(fn, kwargs)
# ---> 52     return fn(*args, **kwargs)
#      53
#      54   return disallow_positional_args_dec(wrapped)  # pylint: disable=no-value-for-parameter
#
# ~\Miniconda3\envs\tf2\lib\site-packages\tensorflow_datasets\core\dataset_builder.py in as_dataset(self, split, batch_size, shuffle_files, decoders, as_supervised, in_memory)
#     418         in_memory=in_memory,
#     419     )
# --> 420     datasets = utils.map_nested(build_single_dataset, split, map_tuple=True)
#     421     return datasets
#     422
#
# ~\Miniconda3\envs\tf2\lib\site-packages\tensorflow_datasets\core\utils\py_utils.py in map_nested(function, data_struct, dict_only, map_tuple)
#     141         return tuple(mapped)
#     142   # Singleton
# --> 143   return function(data_struct)
#     144
#     145
#
# ~\Miniconda3\envs\tf2\lib\site-packages\tensorflow_datasets\core\dataset_builder.py in _build_single_dataset(self, split, shuffle_files, batch_size, decoders, as_supervised, in_memory)
#     488     else:
#     489       dataset = self._as_dataset(
# --> 490           split=split, shuffle_files=shuffle_files, decoders=decoders)
#     491
#     492     if batch_size:
#
# ~\Miniconda3\envs\tf2\lib\site-packages\tensorflow_datasets\core\dataset_builder.py in _as_dataset(self, split, decoders, shuffle_files)
#     830     else:
#     831       # Resolve all the named split tree by real ones
# --> 832       read_instruction = split.get_read_instruction(self.info.splits)
#     833       # Extract the list of SlicedSplitInfo objects containing the splits
#     834       # to use and their associated slice
#
# ~\Miniconda3\envs\tf2\lib\site-packages\tensorflow_datasets\core\splits.py in get_read_instruction(self, split_dict)
#     357
#     358   def get_read_instruction(self, split_dict):
# --> 359     return SplitReadInstruction(split_dict[self._name])
#     360
#     361
#
# ~\Miniconda3\envs\tf2\lib\site-packages\tensorflow_datasets\core\splits.py in __getitem__(self, key)
#     532     if str(key) not in self:
#     533       raise KeyError("Invalid split %s. Available splits are: %s" % (
# --> 534           key, sorted(list(self.keys()))))
#     535     return super(SplitDict, self).__getitem__(str(key))
#     536
#
# KeyError: "Invalid split train[:80%]. Available splits are: ['train']"

# %%
info
# Out:
# tfds.core.DatasetInfo(
#     name='cats_vs_dogs',
#     version=2.0.1,
#     description='A large set of images of cats and dogs.There are 1738 corrupted images that are dropped.',
#     urls=['https://www.microsoft.com/en-us/download/details.aspx?id=54765'],
#     features=FeaturesDict({
#         'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#         'image/filename': Text(shape=(), dtype=tf.string),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=2),
#     }),
#     total_num_examples=23262,
#     splits={
#         'train': 23262,
#     },
#     supervised_keys=('image', 'label'),
#     citation="""@Inproceedings (Conference){asirra-a-captcha-that-exploits-interest-aligned-manual-image-categorization,
#     author = {Elson, Jeremy and Douceur, John (JD) and Howell, Jon and Saul, Jared},
#     title = {Asirra: A CAPTCHA that Exploits Interest-Aligned Manual Image Categorization},
#     booktitle = {Proceedings of 14th ACM Conference on Computer and Communications Security (CCS)},
#     year = {2007},
#     month = {October},
#     publisher = {Association for Computing Machinery, Inc.},
#     url = {https://www.microsoft.com/en-us/research/publication/asirra-a-captcha-that-exploits-interest-aligned-manual-image-categorization/},
#     edition = {Proceedings of 14th ACM Conference on Computer and Communications Security (CCS)},
#     }""",
#     redistribution_info=,
# )

# %%
train = dataset["train"]

# %%
assert isinstance(train, tf.data.Dataset)

# %%
for ex in train.take(1):
    image, label = ex["image"], ex["label"]
    plt.imshow(image.numpy()[:, :, 0].astype(np.float32), cmap=plt.get_cmap("gray"))
    print(label.numpy())
# Out:
# 0
